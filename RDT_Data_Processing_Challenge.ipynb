# %% [markdown]
# <a href="https://colab.research.google.com/github/gomezpaz/datacebo-challenge/blob/main/RDT_Data_Processing_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RDT: Data Processing Challenge
#
# **Your Task**: Use the RDT library to clean and process raw data. The final data you create will be used by the company for machine learning. Refer to [this document](https://docs.google.com/document/d/1T0jX2mNZIPVUb33ONNVQ1QXxK8OjQ6TA82Gm_7v1dUk/edit#heading=h.qcujmb30citt) for detailed instructions.
#
# Please make a copy of this notebook so you can make changes to it.

# %% [markdown]
# ## Install the RDT Library
#
# Install the RDT library by running the code below. After installing the packages, follow the instructions to restart the runtime.
#
# **Note: The newest RDT version is not released yet. We'll install it directly from GitHub.**

# %%
# %pip install git+https://github.com/sdv-dev/RDT.git@v1.0.0.dev

# %% [markdown]
# Then, run the code below to verify that you've installed it properly.

# %%
import rdt 
print(rdt.__version__)
# Out:
# 0.6.5.dev0

# %% [markdown]
# ## Load the data
#
# You should already have the data loaded on your computer. Specify the name of the file in the code below.

# %%
FILENAME = 'customers.csv' # replace this with the name of your file

# %% [markdown]
# Running the cell below will display a button. Use it to select and upload your file.

# %%
import io
import pandas as pd

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b75d9e7-35e8-4a1e-9e51-827b6ffa668a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b75d9e7-35e8-4a1e-9e51-827b6ffa668a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.csv to customers.csv

# %% [markdown]
# The code below will read the file in a variable named `data`. It is a pandas DataFrame object.

# %%
data = pd.read_csv(io.BytesIO(uploaded[FILENAME]))
data
# Out:
#                  customer_email  customer_age customer_subscribed_email  \
# 0      jeffreypatel@example.com           NaN                       NaN
# 1     christinamora@example.com          66.0                       NaN
# 2           chase02@example.org          73.0                      True
# 3       sharpjoshua@example.org          44.0                     False
# 4      walkerronald@example.net           NaN                       NaN
# ...                         ...           ...                       ...
# 2495        glenn84@example.org          37.0                      True
# 2496  heathergibson@example.org          68.0                      True
# 2497     patricia88@example.org          85.0                      True
# 2498   brendagarner@example.com          40.0                      True
# 2499  alexandermark@example.com          47.0                      True
#
#      purchase_date  num_units_purchased  purchase_amount  purchase_promo_code  \
# ...

# %% [markdown]
# # Clean & process the data
#
# Use the space below to clean and process the data. Refer to the [RDT documentation](https://docs.sdv.dev/rdt) to understand the full functionality of the RDT library.

# %%
# Your code here

# %% [markdown]
# # Download your data
#
# After you are done cleaning & processing, use the code below to write the data as a csv file.

# %%
final_data = None # replace with your pandas DataFrame object that contains your final data
final_data.to_csv('processed_customers.csv', index=False)

# %% [markdown]
# You can download the CSV file using the file menu at the left of the Colab notebook. See screenshot below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Questions?
#
# Please don't hesitate to reach out to the SDV team with any questions you have as you work on this task.
